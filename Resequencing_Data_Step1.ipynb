# %%
import pandas as pd
import numpy as np  # 确保导入 numpy
from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# 读取 Excel 文件，并按 'Start' 排序
Input = pd.read_excel("E:/My_python_work_xibanya/LG1678processed.xlsx", sheet_name='LG8')
Input = Input.sort_values(by='POS-2').reset_index(drop=True)

# 定义一个函数来一次性计算 A、H、B、- 的数量
def count_symbols(row):
    counts = (row[7:] == 'A').sum(), (row[7:] == 'H').sum(), (row[7:] == 'B').sum(), (row[7:] == '-').sum()
    return counts

# 应用函数，并将结果分别添加到新的列中
Input[['A_Count', 'H_Count', 'B_Count', '-_Count']] = Input.apply(lambda row: pd.Series(count_symbols(row)), axis=1)

# 定义函数来计算 f(A) 和 f(H)
def calculate_f_a(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = 2 * (A + B + H)
    return (2 * A + H) / denominator if denominator != 0 else np.nan

def calculate_f_h(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = A + B + H
    return H / denominator if denominator != 0 else np.nan

# 计算 f(A) 和 f(H)
Input['f(A)'] = Input.apply(calculate_f_a, axis=1)
Input['f(H)'] = Input.apply(calculate_f_h, axis=1)

# 保存处理后的数据到新的 Excel 工作表
wb = load_workbook("E:/My_python_work_xibanya/LG1678processed.xlsx")
ws = wb.create_sheet("LG8-step1")
for r in dataframe_to_rows(Input, index=False, header=True):
    ws.append(r)
wb.save('E:/My_python_work_xibanya/LG1678processed.xlsx')

# %%
import pandas as pd
import numpy as np  # 确保导入 numpy
from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# 读取 Excel 文件，并按 'Start' 排序
Input = pd.read_excel("E:/My_python_work_xibanya/LG1678processed.xlsx", sheet_name='LG7')
Input = Input.sort_values(by='POS-2').reset_index(drop=True)

# 定义一个函数来一次性计算 A、H、B、- 的数量
def count_symbols(row):
    counts = (row[7:] == 'A').sum(), (row[7:] == 'H').sum(), (row[7:] == 'B').sum(), (row[7:] == '-').sum()
    return counts

# 应用函数，并将结果分别添加到新的列中
Input[['A_Count', 'H_Count', 'B_Count', '-_Count']] = Input.apply(lambda row: pd.Series(count_symbols(row)), axis=1)

# 定义函数来计算 f(A) 和 f(H)
def calculate_f_a(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = 2 * (A + B + H)
    return (2 * A + H) / denominator if denominator != 0 else np.nan

def calculate_f_h(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = A + B + H
    return H / denominator if denominator != 0 else np.nan

# 计算 f(A) 和 f(H)
Input['f(A)'] = Input.apply(calculate_f_a, axis=1)
Input['f(H)'] = Input.apply(calculate_f_h, axis=1)

# 保存处理后的数据到新的 Excel 工作表
wb = load_workbook("E:/My_python_work_xibanya/LG1678processed.xlsx")
ws = wb.create_sheet("LG7-step1")
for r in dataframe_to_rows(Input, index=False, header=True):
    ws.append(r)
wb.save('E:/My_python_work_xibanya/LG1678processed.xlsx')

# %%
import pandas as pd
import numpy as np  # 确保导入 numpy
from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# 读取 Excel 文件，并按 'Start' 排序
Input = pd.read_excel("E:/My_python_work_xibanya/LG1678processed.xlsx", sheet_name='LG6')
Input = Input.sort_values(by='POS-2').reset_index(drop=True)

# 定义一个函数来一次性计算 A、H、B、- 的数量
def count_symbols(row):
    counts = (row[7:] == 'A').sum(), (row[7:] == 'H').sum(), (row[7:] == 'B').sum(), (row[7:] == '-').sum()
    return counts

# 应用函数，并将结果分别添加到新的列中
Input[['A_Count', 'H_Count', 'B_Count', '-_Count']] = Input.apply(lambda row: pd.Series(count_symbols(row)), axis=1)

# 定义函数来计算 f(A) 和 f(H)
def calculate_f_a(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = 2 * (A + B + H)
    return (2 * A + H) / denominator if denominator != 0 else np.nan

def calculate_f_h(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = A + B + H
    return H / denominator if denominator != 0 else np.nan

# 计算 f(A) 和 f(H)
Input['f(A)'] = Input.apply(calculate_f_a, axis=1)
Input['f(H)'] = Input.apply(calculate_f_h, axis=1)

# 保存处理后的数据到新的 Excel 工作表
wb = load_workbook("E:/My_python_work_xibanya/LG1678processed.xlsx")
ws = wb.create_sheet("LG6-step1")
for r in dataframe_to_rows(Input, index=False, header=True):
    ws.append(r)
wb.save('E:/My_python_work_xibanya/LG1678processed.xlsx')

# %%
import pandas as pd
import numpy as np  # 确保导入 numpy
from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# 读取 Excel 文件，并按 'Start' 排序
Input = pd.read_excel("E:/My_python_work_xibanya/LG1678processed.xlsx", sheet_name='LG1')
Input = Input.sort_values(by='POS-2').reset_index(drop=True)

# 定义一个函数来一次性计算 A、H、B、- 的数量
def count_symbols(row):
    counts = (row[7:] == 'A').sum(), (row[7:] == 'H').sum(), (row[7:] == 'B').sum(), (row[7:] == '-').sum()
    return counts

# 应用函数，并将结果分别添加到新的列中
Input[['A_Count', 'H_Count', 'B_Count', '-_Count']] = Input.apply(lambda row: pd.Series(count_symbols(row)), axis=1)

# 定义函数来计算 f(A) 和 f(H)
def calculate_f_a(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = 2 * (A + B + H)
    return (2 * A + H) / denominator if denominator != 0 else np.nan

def calculate_f_h(row):
    A, H, B = row['A_Count'], row['H_Count'], row['B_Count']
    denominator = A + B + H
    return H / denominator if denominator != 0 else np.nan

# 计算 f(A) 和 f(H)
Input['f(A)'] = Input.apply(calculate_f_a, axis=1)
Input['f(H)'] = Input.apply(calculate_f_h, axis=1)

# 保存处理后的数据到新的 Excel 工作表
wb = load_workbook("E:/My_python_work_xibanya/LG1678processed.xlsx")
ws = wb.create_sheet("LG1-step1")
for r in dataframe_to_rows(Input, index=False, header=True):
    ws.append(r)
wb.save('E:/My_python_work_xibanya/LG1678processed.xlsx')

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\annaconda\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in d:\annaconda\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
